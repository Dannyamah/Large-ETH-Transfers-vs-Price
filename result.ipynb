# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From this correlation matrix:
#
# - Whale transfer amount and price change have a moderate negative correlation (-0.39). This suggests that higher whale transfer amounts are somewhat associated with price decreases, but the relationship is not strong.
#
# - Number of transactions and number of whales are extremely highly correlated (0.97), indicating that days with more whale transactions also have more unique whales involved.
#
# - Transactions and price change (0.22) and whales and price change (0.26) show weak positive correlations, meaning more activity is slightly associated with price increases, but the effect is small.
#
# Overall:
# Whale transfer amount is the only metric showing a moderate relationship with price change, and it is negative. Other metrics (transactions, whales) have weak or negligible correlation with price change.
#
# Conclusion:
# Large whale transfers may be linked to price drops, but the number of transactions and whales alone do not strongly predict price movements.
# I will carry out further analysis for deeper insights and update this research
